# %%
import Phase1bVisualizer as vs

# %%
vs.helpVis()
# Out:
#  Use SetIntFileName(_), and if you don't want to use cwd, SetDataDir(__); SetPlotDir(_); SetMovieName(_).
#  Then, doit(<start frame number>, <number of frames>)

# %%
#vs.IntFileName="DroneShort1HalfDecimated.int.1"
vs.SetIntFileName("321-01.int")
vs.SetMovieName("321-01")

# %%
vs.doit(1,200)
#vs.doit(200,200)
#vs.doit(200,400)

# %%
vs.SetIntFileName("321-18.int")
vs.SetMovieName("321-18")
vs.doit(1,200)
