# %%
import Phase1bVisualizer as vs

# %%
vs.helpVis()

# %%
vs.SetResultsDir("/data/GIT/C-TAP/RESULTS-jobDS1HalfDecimatedPIPE")
vs.SetMovieName("DroneShort1HalfDecimated")
vs.SetRunNumber(9)

vs.doit(1,200)
vs.doit(200,200)
vs.doit(400,44)
